# %%
import tensorflow as tf

# Create TensorFlow object called tensor
hello_constant = tf.constant('Hello World!')

with tf.Session() as sess:
    output = sess.run(hello_constant)
    print(output)
# Out:
# b'Hello World!'

# %%
x = tf.placeholder(tf.string)

with tf.Session() as sess:
    output = sess.run(x, feed_dict={x: 'Hello World'})
    print(output)
    output = sess.run(hello_constant)
    print(output)
# Out:
# Hello World
# b'Hello World!'

# %%
y = tf.multiply(2, 5)  # 10
with tf.Session() as sess:
    output = sess.run(y)
    print(output)
# Out:
# 10

# %%
y = tf.subtract(tf.cast(tf.constant(2.0), tf.int32),tf.constant(1)) 
with tf.Session() as sess:
    output = sess.run(y)
    print(output)
# Out:
# 1

# %%
'''
x= 10
y  =2
z = x/y - 1'''

x = tf.constant(10)
y = tf.constant(2)
z = tf.subtract(tf.divide(x, y), tf.cast(tf.constant(1), tf.float64))

with tf.Session() as sess:
    output = sess.run(z)
    print(output)
# Out:
# 4.0

# %%
x = tf.Variable(5)

init = tf.global_variables_initializer()

with tf.Session() as sess:
    sess.run(init)

# %%
n_feature = 120
n_labels = 5

weights = tf.Variable(tf.truncated_normal((n_feature, n_labels)))
bias = tf.Variable(tf.zeros(n_labels))

init = tf.global_variables_initializer()

with tf.Session() as sess:
    sess.run(init)

# %%
import tensorflow as tf
from tensorflow.examples.tutorials.mnist import input_data

# %%
def get_weights(n_features, n_labels):
    return tf.Variable(tf.truncated_normal((n_features, n_labels)))

def get_bias(n_labels):
    return tf.Variable(tf.zeros(n_labels))

def linear(inputs, weight, bias):
    return tf.add(tf.matmul(inputs, weight), bias)

# %%
def mnist_features_labels(n_labels):
    mnist_features = []
    mnist_labels = []
    
    mnist = input_data.read_data_sets('/datasets/ud730/mnist', one_hot=True)
    
    for mnist_feature, mnist_label in zip(*mnist.train.next_batch(10000)):
        if mnist_label[:n_labels].any():
            mnist_features.append(mnist_feature)
            mnist_labels.append(mnist_label[:n_labels])
    return mnist_features, mnist_labels

# %%
n_features = 784
n_labels = 3

features = tf.placeholder(tf.float32)
labels = tf.placeholder(tf.float32)

w = get_weights(n_features, n_labels)
b= get_bias(n_labels)

logits = linear(features, w, b)

train_features, train_labels = mnist_features_labels(n_labels)

with tf.Session() as sess:
    
    sess.run(tf.global_variables_initializer())
    
    prediction = tf.nn.softmax(logits)
    
    cross_entropy = -tf.reduce_sum(labels * tf.log(prediction), reduction_indices=1)
    
    loss = tf.reduce_mean(cross_entropy)
    
    learning_rate = 0.08
    
    optimizer = tf.train.GradientDescentOptimizer(learning_rate).minimize(loss)
    
    _,l = sess.run(
        [optimizer, loss],
        feed_dict={features:train_features, labels:train_labels})
    print(cross_entropy.value_index)

print("Loss", l)
# Out:
# Extracting /datasets/ud730/mnist\train-images-idx3-ubyte.gz
# Extracting /datasets/ud730/mnist\train-labels-idx1-ubyte.gz
# Extracting /datasets/ud730/mnist\t10k-images-idx3-ubyte.gz
# Extracting /datasets/ud730/mnist\t10k-labels-idx1-ubyte.gz
# 0
# Loss 8.7947

# %%
import math
def batches(batch_size, features, labels):
    """
    Create batches of features and labels
    :param batch_size: The batch size
    :param features: List of features
    :param labels: List of labels
    :return: Batches of (Features, Labels)
    """
    num_batches = len(labels) // batch_size
    last_batch = len(labels) % batch_size
    batch = []*(num_batches + 1)
    i = 0
    while(i < num_batches):
        chunk = i * batch_size
        #print ("i {} chunk size {}".format(i, chunk))
        batch.append([features[chunk:chunk+batch_size], labels[chunk:chunk+batch_size]])
        i += 1
    chunk = i * last_batch
    batch.append([features[chunk:chunk+last_batch], labels[chunk:chunk+last_batch]])
    return batch

# %%
from pprint import pprint

# 4 Samples of features
example_features = [
    ['F11','F12','F13','F14'],
    ['F21','F22','F23','F24'],
    ['F31','F32','F33','F34'],
    ['F41','F42','F43','F44']]
# 4 Samples of labels
example_labels = [
    ['L11','L12'],
    ['L21','L22'],
    ['L31','L32'],
    ['L41','L42']]

# PPrint prints data structures like 2d arrays, so they are easier to read
pprint(batches(3, example_features, example_labels))
# Out:
# i 0 chunk size 0
# [[[['F11', 'F12', 'F13', 'F14'],
#    ['F21', 'F22', 'F23', 'F24'],
#    ['F31', 'F32', 'F33', 'F34']],
#   [['L11', 'L12'], ['L21', 'L22'], ['L31', 'L32']]],
#  [[['F21', 'F22', 'F23', 'F24']], [['L21', 'L22']]]]

# %%
from tensorflow.examples.tutorials.mnist import input_data
import tensorflow as tf
import numpy as np

learning_rate = 0.001
n_input = 784  # MNIST data input (img shape: 28*28)
n_classes = 10  # MNIST total classes (0-9 digits)


# Import MNIST data
mnist = input_data.read_data_sets('/datasets/ud730/mnist', one_hot=True)


# The features are already scaled and the data is shuffled
train_features = mnist.train.images
test_features = mnist.test.images

train_labels = mnist.train.labels.astype(np.float32)
test_labels = mnist.test.labels.astype(np.float32)

features = tf.placeholder(tf.float32, [None, n_input])
labels = tf.placeholder(tf.float32, [None, n_classes])

weights = tf.Variable(tf.truncated_normal([n_input, n_classes]))
bias = tf.Variable(tf.truncated_normal([n_classes]))

logits = tf.add(tf.matmul(features, weights), bias)

cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels = labels, logits=logits))
optimizer = tf.train.GradientDescentOptimizer(learning_rate=learning_rate).minimize(cost)

correct_prediction = tf.equal(tf.argmax(logits, 1), tf.argmax(labels, 1))
accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))

batch_size = 128

init = tf.global_variables_initializer()

with tf.Session() as sess:
    
    sess.run(init)
    
    batch = batches(batch_size, train_features, train_labels)
    
    for batch_features, batch_labels in batch:
        sess.run(optimizer, feed_dict={features:batch_features, labels:batch_labels})

    sess.run(accuracy, feed_dict={features:test_features, labels:test_labels})
print("Test Accuracy {}".format(accuracy))
# Out:
# Extracting /datasets/ud730/mnist\train-images-idx3-ubyte.gz
# Extracting /datasets/ud730/mnist\train-labels-idx1-ubyte.gz
# Extracting /datasets/ud730/mnist\t10k-images-idx3-ubyte.gz
# Extracting /datasets/ud730/mnist\t10k-labels-idx1-ubyte.gz
# i 0 chunk size 0
# i 1 chunk size 128
# i 2 chunk size 256
# i 3 chunk size 384
# i 4 chunk size 512
# i 5 chunk size 640
# i 6 chunk size 768
# i 7 chunk size 896
# i 8 chunk size 1024
# i 9 chunk size 1152
# i 10 chunk size 1280
# i 11 chunk size 1408
# i 12 chunk size 1536
# i 13 chunk size 1664
# i 14 chunk size 1792
# i 15 chunk size 1920
# i 16 chunk size 2048
# i 17 chunk size 2176
# i 18 chunk size 2304
# i 19 chunk size 2432
# i 20 chunk size 2560
# i 21 chunk size 2688
# i 22 chunk size 2816
# i 23 chunk size 2944
# i 24 chunk size 3072
# i 25 chunk size 3200
# i 26 chunk size 3328
# i 27 chunk size 3456
# i 28 chunk size 3584
# i 29 chunk size 3712
# i 30 chunk size 3840
# i 31 chunk size 3968
# i 32 chunk size 4096
# i 33 chunk size 4224
# i 34 chunk size 4352
# i 35 chunk size 4480
# i 36 chunk size 4608
# i 37 chunk size 4736
# i 38 chunk size 4864
# i 39 chunk size 4992
# i 40 chunk size 5120
# i 41 chunk size 5248
# i 42 chunk size 5376
# i 43 chunk size 5504
# i 44 chunk size 5632
# i 45 chunk size 5760
# i 46 chunk size 5888
# i 47 chunk size 6016
# i 48 chunk size 6144
# i 49 chunk size 6272
# i 50 chunk size 6400
# i 51 chunk size 6528
# i 52 chunk size 6656
# i 53 chunk size 6784
# i 54 chunk size 6912
# i 55 chunk size 7040
# i 56 chunk size 7168
# i 57 chunk size 7296
# i 58 chunk size 7424
# i 59 chunk size 7552
# i 60 chunk size 7680
# i 61 chunk size 7808
# i 62 chunk size 7936
# i 63 chunk size 8064
# i 64 chunk size 8192
# i 65 chunk size 8320
# i 66 chunk size 8448
# i 67 chunk size 8576
# i 68 chunk size 8704
# i 69 chunk size 8832
# i 70 chunk size 8960
# i 71 chunk size 9088
# i 72 chunk size 9216
# i 73 chunk size 9344
# i 74 chunk size 9472
# i 75 chunk size 9600
# i 76 chunk size 9728
# i 77 chunk size 9856
# i 78 chunk size 9984
# i 79 chunk size 10112
# i 80 chunk size 10240
# i 81 chunk size 10368
# i 82 chunk size 10496
# i 83 chunk size 10624
# i 84 chunk size 10752
# i 85 chunk size 10880
# i 86 chunk size 11008
# i 87 chunk size 11136
# i 88 chunk size 11264
# i 89 chunk size 11392
# i 90 chunk size 11520
# i 91 chunk size 11648
# i 92 chunk size 11776
# i 93 chunk size 11904
# i 94 chunk size 12032
# i 95 chunk size 12160
# i 96 chunk size 12288
# i 97 chunk size 12416
# i 98 chunk size 12544
# i 99 chunk size 12672
# i 100 chunk size 12800
# i 101 chunk size 12928
# i 102 chunk size 13056
# i 103 chunk size 13184
# i 104 chunk size 13312
# i 105 chunk size 13440
# i 106 chunk size 13568
# i 107 chunk size 13696
# i 108 chunk size 13824
# i 109 chunk size 13952
# i 110 chunk size 14080
# i 111 chunk size 14208
# i 112 chunk size 14336
# i 113 chunk size 14464
# i 114 chunk size 14592
# i 115 chunk size 14720
# i 116 chunk size 14848
# i 117 chunk size 14976
# i 118 chunk size 15104
# i 119 chunk size 15232
# i 120 chunk size 15360
# i 121 chunk size 15488
# i 122 chunk size 15616
# i 123 chunk size 15744
# i 124 chunk size 15872
# i 125 chunk size 16000
# i 126 chunk size 16128
# i 127 chunk size 16256
# i 128 chunk size 16384
# i 129 chunk size 16512
# i 130 chunk size 16640
# i 131 chunk size 16768
# i 132 chunk size 16896
# i 133 chunk size 17024
# i 134 chunk size 17152
# i 135 chunk size 17280
# i 136 chunk size 17408
# i 137 chunk size 17536
# i 138 chunk size 17664
# i 139 chunk size 17792
# i 140 chunk size 17920
# i 141 chunk size 18048
# i 142 chunk size 18176
# i 143 chunk size 18304
# i 144 chunk size 18432
# i 145 chunk size 18560
# i 146 chunk size 18688
# i 147 chunk size 18816
# i 148 chunk size 18944
# i 149 chunk size 19072
# i 150 chunk size 19200
# i 151 chunk size 19328
# i 152 chunk size 19456
# i 153 chunk size 19584
# i 154 chunk size 19712
# i 155 chunk size 19840
# i 156 chunk size 19968
# i 157 chunk size 20096
# i 158 chunk size 20224
# i 159 chunk size 20352
# i 160 chunk size 20480
# i 161 chunk size 20608
# i 162 chunk size 20736
# i 163 chunk size 20864
# i 164 chunk size 20992
# i 165 chunk size 21120
# i 166 chunk size 21248
# i 167 chunk size 21376
# i 168 chunk size 21504
# i 169 chunk size 21632
# i 170 chunk size 21760
# i 171 chunk size 21888
# i 172 chunk size 22016
# i 173 chunk size 22144
# i 174 chunk size 22272
# i 175 chunk size 22400
# i 176 chunk size 22528
# i 177 chunk size 22656
# i 178 chunk size 22784
# i 179 chunk size 22912
# i 180 chunk size 23040
# i 181 chunk size 23168
# i 182 chunk size 23296
# i 183 chunk size 23424
# i 184 chunk size 23552
# i 185 chunk size 23680
# i 186 chunk size 23808
# i 187 chunk size 23936
# i 188 chunk size 24064
# i 189 chunk size 24192
# i 190 chunk size 24320
# i 191 chunk size 24448
# i 192 chunk size 24576
# i 193 chunk size 24704
# i 194 chunk size 24832
# i 195 chunk size 24960
# i 196 chunk size 25088
# i 197 chunk size 25216
# i 198 chunk size 25344
# i 199 chunk size 25472
# i 200 chunk size 25600
# i 201 chunk size 25728
# i 202 chunk size 25856
# i 203 chunk size 25984
# i 204 chunk size 26112
# i 205 chunk size 26240
# i 206 chunk size 26368
# i 207 chunk size 26496
# i 208 chunk size 26624
# i 209 chunk size 26752
# i 210 chunk size 26880
# i 211 chunk size 27008
# i 212 chunk size 27136
# i 213 chunk size 27264
# i 214 chunk size 27392
# i 215 chunk size 27520
# i 216 chunk size 27648
# i 217 chunk size 27776
# i 218 chunk size 27904
# i 219 chunk size 28032
# i 220 chunk size 28160
# i 221 chunk size 28288
# i 222 chunk size 28416
# i 223 chunk size 28544
# i 224 chunk size 28672
# i 225 chunk size 28800
# i 226 chunk size 28928
# i 227 chunk size 29056
# i 228 chunk size 29184
# i 229 chunk size 29312
# i 230 chunk size 29440
# i 231 chunk size 29568
# i 232 chunk size 29696
# i 233 chunk size 29824
# i 234 chunk size 29952
# i 235 chunk size 30080
# i 236 chunk size 30208
# i 237 chunk size 30336
# i 238 chunk size 30464
# i 239 chunk size 30592
# i 240 chunk size 30720
# i 241 chunk size 30848
# i 242 chunk size 30976
# i 243 chunk size 31104
# i 244 chunk size 31232
# i 245 chunk size 31360
# i 246 chunk size 31488
# i 247 chunk size 31616
# i 248 chunk size 31744
# i 249 chunk size 31872
# i 250 chunk size 32000
# i 251 chunk size 32128
# i 252 chunk size 32256
# i 253 chunk size 32384
# i 254 chunk size 32512
# i 255 chunk size 32640
# i 256 chunk size 32768
# i 257 chunk size 32896
# i 258 chunk size 33024
# i 259 chunk size 33152
# i 260 chunk size 33280
# i 261 chunk size 33408
# i 262 chunk size 33536
# i 263 chunk size 33664
# i 264 chunk size 33792
# i 265 chunk size 33920
# i 266 chunk size 34048
# i 267 chunk size 34176
# i 268 chunk size 34304
# i 269 chunk size 34432
# i 270 chunk size 34560
# i 271 chunk size 34688
# i 272 chunk size 34816
# i 273 chunk size 34944
# i 274 chunk size 35072
# i 275 chunk size 35200
# i 276 chunk size 35328
# i 277 chunk size 35456
# i 278 chunk size 35584
# i 279 chunk size 35712
# i 280 chunk size 35840
# i 281 chunk size 35968
# i 282 chunk size 36096
# i 283 chunk size 36224
# i 284 chunk size 36352
# i 285 chunk size 36480
# i 286 chunk size 36608
# i 287 chunk size 36736
# i 288 chunk size 36864
# i 289 chunk size 36992
# i 290 chunk size 37120
# i 291 chunk size 37248
# i 292 chunk size 37376
# i 293 chunk size 37504
# i 294 chunk size 37632
# i 295 chunk size 37760
# i 296 chunk size 37888
# i 297 chunk size 38016
# i 298 chunk size 38144
# i 299 chunk size 38272
# i 300 chunk size 38400
# i 301 chunk size 38528
# i 302 chunk size 38656
# i 303 chunk size 38784
# i 304 chunk size 38912
# i 305 chunk size 39040
# i 306 chunk size 39168
# i 307 chunk size 39296
# i 308 chunk size 39424
# i 309 chunk size 39552
# i 310 chunk size 39680
# i 311 chunk size 39808
# i 312 chunk size 39936
# i 313 chunk size 40064
# i 314 chunk size 40192
# i 315 chunk size 40320
# i 316 chunk size 40448
# i 317 chunk size 40576
# i 318 chunk size 40704
# i 319 chunk size 40832
# i 320 chunk size 40960
# i 321 chunk size 41088
# i 322 chunk size 41216
# i 323 chunk size 41344
# i 324 chunk size 41472
# i 325 chunk size 41600
# i 326 chunk size 41728
# i 327 chunk size 41856
# i 328 chunk size 41984
# i 329 chunk size 42112
# i 330 chunk size 42240
# i 331 chunk size 42368
# i 332 chunk size 42496
# i 333 chunk size 42624
# i 334 chunk size 42752
# i 335 chunk size 42880
# i 336 chunk size 43008
# i 337 chunk size 43136
# i 338 chunk size 43264
# i 339 chunk size 43392
# i 340 chunk size 43520
# i 341 chunk size 43648
# i 342 chunk size 43776
# i 343 chunk size 43904
# i 344 chunk size 44032
# i 345 chunk size 44160
# i 346 chunk size 44288
# i 347 chunk size 44416
# i 348 chunk size 44544
# i 349 chunk size 44672
# i 350 chunk size 44800
# i 351 chunk size 44928
# i 352 chunk size 45056
# i 353 chunk size 45184
# i 354 chunk size 45312
# i 355 chunk size 45440
# i 356 chunk size 45568
# i 357 chunk size 45696
# i 358 chunk size 45824
# i 359 chunk size 45952
# i 360 chunk size 46080
# i 361 chunk size 46208
# i 362 chunk size 46336
# i 363 chunk size 46464
# i 364 chunk size 46592
# i 365 chunk size 46720
# i 366 chunk size 46848
# i 367 chunk size 46976
# i 368 chunk size 47104
# i 369 chunk size 47232
# i 370 chunk size 47360
# i 371 chunk size 47488
# i 372 chunk size 47616
# i 373 chunk size 47744
# i 374 chunk size 47872
# i 375 chunk size 48000
# i 376 chunk size 48128
# i 377 chunk size 48256
# i 378 chunk size 48384
# i 379 chunk size 48512
# i 380 chunk size 48640
# i 381 chunk size 48768
# i 382 chunk size 48896
# i 383 chunk size 49024
# i 384 chunk size 49152
# i 385 chunk size 49280
# i 386 chunk size 49408
# i 387 chunk size 49536
# i 388 chunk size 49664
# i 389 chunk size 49792
# i 390 chunk size 49920
# i 391 chunk size 50048
# i 392 chunk size 50176
# i 393 chunk size 50304
# i 394 chunk size 50432
# i 395 chunk size 50560
# i 396 chunk size 50688
# i 397 chunk size 50816
# i 398 chunk size 50944
# i 399 chunk size 51072
# i 400 chunk size 51200
# i 401 chunk size 51328
# i 402 chunk size 51456
# i 403 chunk size 51584
# i 404 chunk size 51712
# i 405 chunk size 51840
# i 406 chunk size 51968
# i 407 chunk size 52096
# i 408 chunk size 52224
# i 409 chunk size 52352
# i 410 chunk size 52480
# i 411 chunk size 52608
# i 412 chunk size 52736
# i 413 chunk size 52864
# i 414 chunk size 52992
# i 415 chunk size 53120
# i 416 chunk size 53248
# i 417 chunk size 53376
# i 418 chunk size 53504
# i 419 chunk size 53632
# i 420 chunk size 53760
# i 421 chunk size 53888
# i 422 chunk size 54016
# i 423 chunk size 54144
# i 424 chunk size 54272
# i 425 chunk size 54400
# i 426 chunk size 54528
# i 427 chunk size 54656
# i 428 chunk size 54784
# Test Accuracy Tensor("Mean_10:0", shape=(), dtype=float32)
